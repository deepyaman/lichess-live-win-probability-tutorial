# %%
import ibis
from ibis import _

# %% [markdown]
# # Connect to Starburst Galaxy
#
# First, connect to Starburst Galaxy. We’ll use a `.env` in this example for secrets that are loaded as environment variables. This requires installing the `python-dotenv` package—alternatively, you can set the environment variables for your system.

# %%
import os

from dotenv import load_dotenv
from trino.auth import BasicAuthentication

load_dotenv()

user = os.getenv("TRINO_USERNAME")
password = os.getenv("TRINO_PASSWORD")
host = os.getenv("TRINO_HOSTNAME")
port = os.getenv("TRINO_PORTNUMBER")
catalog = "lichess"
schema = "lichess"

con = ibis.trino.connect(
    user=user,
    password=BasicAuthentication(user, password),
    host=host,
    port=port,
    database=catalog,
    schema=schema,
    roles="accountadmin",
    http_scheme="https",
)
con
# Out:
# /workspaces/lichess-live-win-probability-tutorial/.venv/lib/python3.12/site-packages/ibis/backends/trino/__init__.py:314: FutureWarning: The `password` parameter is deprecated and will be removed in 10.0; use `auth` instead
#   warnings.warn(

# %% [markdown]
# # Verify connection
#
# List the tables your connection has:

# %%
con.list_tables()
# Out:
# ['games', 'moves']

# %% [markdown]
# Run a SQL query:

# %%
con.sql("SELECT * FROM games LIMIT 10").execute()
# Out:
#     game_id              event                          site        date  \
# 0  34brw9vk  Rated Bullet game  https://lichess.org/34brw9vk  2024.09.22
# 1  J9H1AkSC   Rated Blitz game  https://lichess.org/J9H1AkSC  2024.09.22
# 2  Lypztt25  Rated Bullet game  https://lichess.org/Lypztt25  2024.09.22
# 3  0ZR17pZf  Rated Bullet game  https://lichess.org/0ZR17pZf  2024.09.22
# 4  aOmkkHVx  Rated Bullet game  https://lichess.org/aOmkkHVx  2024.09.22
# 5  ngZQxKij  Rated Bullet game  https://lichess.org/ngZQxKij  2024.09.22
# 6  4NEcW1Hy  Rated Bullet game  https://lichess.org/4NEcW1Hy  2024.09.22
# 7  hoRDhHhz  Rated Bullet game  https://lichess.org/hoRDhHhz  2024.09.22
# 8  S11VRbM5  Rated Bullet game  https://lichess.org/S11VRbM5  2024.09.22
# 9  rteScC62  Rated Bullet game  https://lichess.org/rteScC62  2024.09.22
#
#   round                 white            black result    utc_date  utc_time  \
# 0     -            sriishanth      ali7_azimi7    0-1  2024.09.22  02:57:47
# 1     -             asysyarof  jaygonzales1202    1-0  2024.09.22  02:57:47
# 2     -            martinde25    beetlejuice64    1-0  2024.09.22  02:57:48
# 3     -  Homo_Sapiens_Natural          utchemy    0-1  2024.09.22  02:57:48
# 4     -                M4yank     Andrey_Lysov    1-0  2024.09.22  02:57:48
# 5     -               iiliiyo     Elgranconejo    0-1  2024.09.22  02:57:48
# 6     -                MSSAAD         reizinho    0-1  2024.09.22  02:57:48
# 7     -              bivalves     mountainflea    1-0  2024.09.22  02:57:48
# 8     -          sandrodaniel      Dewakipascs    0-1  2024.09.22  02:57:48
# 9     -    rinaakbar_luwu2014           HYCUTE    1-0  2024.09.22  02:57:48
#
#   white_elo black_elo white_rating_diff black_rating_diff  eco  \
# 0      1906      1973                -9                +5  A03
# 1      1893      1892                +6                -5  B10
# 2      1930      1978                +7                -7  E90
# 3      1265      1259                -6                +8  C20
# 4      2391      2372                +5                -6  C00
# 5      2588      2614                -5                +5  D00
# 6      2131      2131                -6                +5  D00
# 7      1442      1317                +3                -5  C58
# 8      2302      2205                -7                +7  D00
# 9      2162      2108                +5                -4  A00
#
#                                              opening time_control  \
# 0                      Bird Opening: Dutch Variation         60+2
# 1        Caro-Kann Defense: Accelerated Panov Attack        180+0
# 2  King's Indian Defense: Normal Variation, Rare ...         60+0
# 3              King's Pawn Game: Leonardis Variation         60+0
# 4                     French Defense: Queen's Knight         60+0
# 5              Queen's Pawn Game: Chigorin Variation         60+0
# 6  Queen's Pawn Game: Accelerated London System, ...         60+0
# 7  Italian Game: Two Knights Defense, Polerio Def...         60+0
# 8                                  Queen's Pawn Game         60+0
# 9                                      Kádas Opening         60+0
#
#     termination white_title black_title
# 0        Normal        None        None
# 1        Normal        None        None
# 2  Time forfeit        None        None
# 3  Time forfeit        None        None
# 4  Time forfeit        None        None
# 5  Time forfeit        None        None
# 6  Time forfeit        None        None
# 7  Time forfeit        None        None
# 8        Normal        None        None
# 9        Normal        None        None

# %% [markdown]
# # Filter out games without evals

# %%
unfiltered_games = con.table("games")
unfiltered_games.count().to_pyarrow().as_py()
# Out:
# 87713219

# %%
unfiltered_moves = con.table("moves")
unfiltered_moves.count().to_pyarrow().as_py()
# Out:
# 5837064712

# %%
games_with_evals = (
    unfiltered_moves.mutate(has_eval=_.comment.contains("[%eval"))
    .group_by(_.game_id)
    .agg(
        percent_has_eval=_.has_eval.mean(),
        has_no_eval_count=_.count() - _.has_eval.sum(),
    )
    .mutate(
        has_no_eval_count=ibis.ifelse(_.percent_has_eval == 0, -1, _.has_no_eval_count)
    )
    .filter(_.has_no_eval_count.between(0, 1))
)
games_with_evals.count().to_pyarrow().as_py()
# Out:
# 7933774

# %%
games = games_with_evals.select("game_id").join(unfiltered_games, "game_id")
games.count().to_pyarrow().as_py()
# Out:
# 7933774

# %%
moves = games_with_evals.select("game_id").join(unfiltered_moves, "game_id")
moves.count().to_pyarrow().as_py()
# Out:
# 519982245

# %% [markdown]
# # Create game-level features

# %%
game_level_features = []

# %% [markdown]
# ## `event`-based features

# %%
is_rated = games.event.startswith("Rated ")
game_level_features.append(is_rated.name("is_rated"))

# %%
event_with_rated_prefix_stripped = is_rated.ifelse(
    games.event[len("Rated ") :], games.event
)
lichess_time_control_type = event_with_rated_prefix_stripped.substr(
    0, event_with_rated_prefix_stripped.find(" ")
)
game_level_features.append(lichess_time_control_type.name("lichess_time_control_type"))

# %%
is_tournament = games.event.contains("tournament")
game_level_features.append(is_tournament.name("is_tournament"))

# %% [markdown]
# ## Elo-based features

# %%
white_elo = games.white_elo.cast(int)
game_level_features.append(white_elo.name("white_elo"))

# %%
black_elo = games.black_elo.cast(int)
game_level_features.append(black_elo.name("black_elo"))

# %% [markdown]
# ## Title features

# %%
white_title = games.white_title
game_level_features.append(white_title.name("white_title"))

# %%
black_title = games.black_title
game_level_features.append(black_title.name("black_title"))

# %% [markdown]
# ## `time_control`-based features

# %%
index = games.time_control.find("+")
base_time = games.time_control.substr(0, index).try_cast(int)
increment = games.time_control.substr(index + 1).try_cast(int)
game_level_features += [
    base_time.name("base_time"),
    increment.name("increment"),
]

# %% [markdown]
# ## Target variable

# %%
target = games.result.case().when("1-0", 1).when("1/2-1/2", 0.5).when("0-1", 0).end()
game_level_features.append(target.name("target"))

# %% [markdown]
# # Create move-level features
#
# ## Eval-based features

# %%
eval_based_features = []

# %%
moves_with_parsed_eval = moves.alias("moves").sql(
    r"""
        SELECT
          *,
          REGEXP_EXTRACT(
            comment,
            '\[%eval\s(\#[+-]?\d+)|([+-]?\d{0,10}\.\d{1,2}|\d{1,10}\.?)',
            1
          ) AS mate,
          REGEXP_EXTRACT(
            comment,
            '\[%eval\s(\#[+-]?\d+)|([+-]?\d{0,10}\.\d{1,2}|\d{1,10}\.?)',
            2
          ) AS regular_eval
        FROM moves
        """
)
moves_with_parsed_eval
# Out:
# r0 := DatabaseTable: moves
#   game_id string
#   ply     int64
#   comment string
#
# r1 := Project[r0]
#   game_id:  r0.game_id
#   ply:      r0.ply
#   comment:  r0.comment
#   has_eval: StringContains(haystack=r0.comment, needle='[%eval')
#
# r2 := Aggregate[r1]
#   groups:
#     game_id: r1.game_id
#   metrics:
#     percent_has_eval:  Mean(r1.has_eval)
#     has_no_eval_count: CountStar(r1) - Sum(r1.has_eval)
#
# r3 := Project[r2]
#   game_id:           r2.game_id
#   percent_has_eval:  r2.percent_has_eval
#   has_no_eval_count: IfElse(bool_expr=r2.percent_has_eval == 0, true_expr=-1, false_null_expr=r2.has_no_eval_count)
#
# r4 := Filter[r3]
#   Between(r3.has_no_eval_count, lower_bound=0, upper_bound=1)
#
# r5 := Project[r4]
#   game_id: r4.game_id
#
# r6 := JoinChain[r5]
#   JoinLink[inner, r0]
#     r5.game_id == r0.game_id
#   values:
#     game_id: r5.game_id
#     ply:     r0.ply
#     comment: r0.comment
#
# r7 := View: moves
#   game_id string
#   ply     int64
#   comment string
#
# SQLStringView[r7]
#   query:
#     SELECT *, REGEXP_EXTRACT( comment, …
#   schema:
#     game_id      string
#     ply          int64
#     comment      string
#     mate         string
#     regular_eval string

# %%
MATE_SCORE = 1_000  # Arbitrary large number greater than 121 (`max(abs(mate))`)

mate_eval = moves_with_parsed_eval.mate.substr(1).try_cast(
    int
).sign() * MATE_SCORE - moves_with_parsed_eval.mate.substr(1).try_cast(int)
eval_based_features += [
    mate_eval.name("mate_eval"),
    moves_with_parsed_eval.regular_eval.try_cast("float").name("regular_eval"),
]

# %% [markdown]
# ## Clock-based features

# %%
clock_based_features = []

# %%
moves_with_parsed_clock = moves.alias("moves").sql(
    r"""
        SELECT
          *,
          REGEXP_EXTRACT(
            comment,
            '\[%clk\s(\d+):(\d+):(\d+)\]',
            1
          ) AS hours,
          REGEXP_EXTRACT(
            comment,
            '\[%clk\s(\d+):(\d+):(\d+)\]',
            2
          ) AS minutes,
          REGEXP_EXTRACT(
            comment,
            '\[%clk\s(\d+):(\d+):(\d+)\]',
            3
          ) AS seconds
        FROM moves
        """
)
moves_with_parsed_clock
# Out:
# r0 := DatabaseTable: moves
#   game_id string
#   ply     int64
#   comment string
#
# r1 := Project[r0]
#   game_id:  r0.game_id
#   ply:      r0.ply
#   comment:  r0.comment
#   has_eval: StringContains(haystack=r0.comment, needle='[%eval')
#
# r2 := Aggregate[r1]
#   groups:
#     game_id: r1.game_id
#   metrics:
#     percent_has_eval:  Mean(r1.has_eval)
#     has_no_eval_count: CountStar(r1) - Sum(r1.has_eval)
#
# r3 := Project[r2]
#   game_id:           r2.game_id
#   percent_has_eval:  r2.percent_has_eval
#   has_no_eval_count: IfElse(bool_expr=r2.percent_has_eval == 0, true_expr=-1, false_null_expr=r2.has_no_eval_count)
#
# r4 := Filter[r3]
#   Between(r3.has_no_eval_count, lower_bound=0, upper_bound=1)
#
# r5 := Project[r4]
#   game_id: r4.game_id
#
# r6 := JoinChain[r5]
#   JoinLink[inner, r0]
#     r5.game_id == r0.game_id
#   values:
#     game_id: r5.game_id
#     ply:     r0.ply
#     comment: r0.comment
#
# r7 := View: moves
#   game_id string
#   ply     int64
#   comment string
#
# SQLStringView[r7]
#   query:
#     SELECT *, REGEXP_EXTRACT( comment, '\[%clk\s(\d+):(\d+):(\d+)\]', 1 ) AS …
#   schema:
#     game_id string
#     ply     int64
#     comment string
#     hours   string
#     minutes string
#     seconds string

# %%
clock = (
    moves_with_parsed_clock.hours.try_cast(int) * 3600
    + moves_with_parsed_clock.minutes.try_cast(int) * 60
    + moves_with_parsed_clock.seconds.try_cast(float)
)

# %%
w = ibis.window(group_by="game_id", order_by="ply")
previous_clock = clock.lag().over(w)
white_clock = ibis.ifelse(moves_with_parsed_clock.ply % 2 == 1, clock, previous_clock)
black_clock = ibis.ifelse(moves_with_parsed_clock.ply % 2 == 0, clock, previous_clock)
black_clock = black_clock.coalesce(white_clock)
clock_based_features += [
    white_clock.name("white_clock"),
    black_clock.name("black_clock"),
]

# %% [markdown]
# # Create model input table

# %%
move_level_features = moves_with_parsed_eval.select(
    "game_id", "ply", *eval_based_features
).join(
    moves_with_parsed_clock.select("game_id", "ply", *clock_based_features),
    ["game_id", "ply"],
)
model_input_table = games.select("game_id", *game_level_features).join(
    move_level_features, "game_id"
)
model_input_table
# Out:
# r0 := DatabaseTable: games
#   game_id           string
#   event             string
#   site              string
#   date              string
#   round             string
#   white             string
#   black             string
#   result            string
#   utc_date          string
#   utc_time          string
#   white_elo         string
#   black_elo         string
#   white_rating_diff string
#   black_rating_diff string
#   eco               string
#   opening           string
#   time_control      string
#   termination       string
#   white_title       string
#   black_title       string
#
# r1 := DatabaseTable: moves
#   game_id string
#   ply     int64
#   comment string
#
# r2 := Project[r1]
#   game_id:  r1.game_id
#   ply:      r1.ply
#   comment:  r1.comment
#   has_eval: StringContains(haystack=r1.comment, needle='[%eval')
#
# r3 := Aggregate[r2]
#   groups:
#     game_id: r2.game_id
#   metrics:
#     percent_has_eval:  Mean(r2.has_eval)
#     has_no_eval_count: CountStar(r2) - Sum(r2.has_eval)
#
# r4 := Project[r3]
#   game_id:           r3.game_id
#   percent_has_eval:  r3.percent_has_eval
#   has_no_eval_count: IfElse(bool_expr=r3.percent_has_eval == 0, true_expr=-1, false_null_expr=r3.has_no_eval_count)
#
# r5 := Filter[r4]
#   Between(r4.has_no_eval_count, lower_bound=0, upper_bound=1)
#
# r6 := Project[r5]
#   game_id: r5.game_id
#
# r7 := JoinChain[r6]
#   JoinLink[inner, r1]
#     r6.game_id == r1.game_id
#   values:
#     game_id: r6.game_id
#     ply:     r1.ply
#     comment: r1.comment
#
# r8 := View: moves
#   game_id string
#   ply     int64
#   comment string
#
# r9 := SQLStringView[r8]
#   query:
#     SELECT *, REGEXP_EXTRACT( comment, …
#   schema:
#     game_id      string
#     ply          int64
#     comment      string
#     mate         string
#     regular_eval string
#
# r10 := SQLStringView[r8]
#   query:
#     SELECT *, REGEXP_EXTRACT( comment, '\[%clk\s(\d+):(\d+):(\d+)\]', 1 ) AS …
#   schema:
#     game_id string
#     ply     int64
#     comment string
#     hours   string
#     minutes string
#     seconds string
#
# r11 := Project[r9]
#   game_id:      r9.game_id
#   ply:          r9.ply
#   mate_eval:    Sign(TryCast(Substring(r9.mate, start=1), to=int64)) * 1000 - TryCast(Substring(r9.mate, start=1), to=int64)
#   regular_eval: TryCast(r9.regular_eval, to=float64)
#
# r12 := Project[r10]
#   game_id:     r10.game_id
#   ply:         r10.ply
#   white_clock: IfElse(bool_expr=r10.ply % 2 == 1, true_expr=TryCast(r10.hours, to=int64) * 3600 + TryCast(r10.minutes, to=int64) * 60 + TryCast(r10.seconds, to=float64), false_null_expr=WindowFunction(func=Lag(TryCast(r10.hours, to=int64) * 3600 + TryCast(r10.minutes, to=int64) * 60 + TryCast(r10.seconds, to=float64)), how='rows', group_by=[r10.game_id], order_by=[asc r10.ply]))
#   black_clock: Coalesce([IfElse(bool_expr=r10.ply % 2 == 0, true_expr=TryCast(r10.hours, to=int64) * 3600 + TryCast(r10.minutes, to=int64) * 60 + TryCast(r10.seconds, to=float64), false_null_expr=WindowFunction(func=Lag(TryCast(r10.hours, to=int64) * 3600 + TryCast(r10.minutes, to=int64) * 60 + TryCast(r10.seconds, to=float64)), how='rows', group_by=[r10.game_id], order_by=[asc r10.ply])), IfElse(bool_expr=r10.ply % 2 == 1, true_expr=TryCast(r10.hours, to=int64) * 3600 + TryCast(r10.minutes, to=int64) * 60 + TryCast(r10.seconds, to=float64), false_null_expr=WindowFunction(func=Lag(TryCast(r10.hours, to=int64) * 3600 + TryCast(r10.minutes, to=int64) * 60 + TryCast(r10.seconds, to=float64)), how='rows', group_by=[r10.game_id], order_by=[asc r10.ply]))])
#
# r13 := JoinChain[r11]
#   JoinLink[inner, r12]
#     r11.game_id == r12.game_id
#     r11.ply == r12.ply
#   values:
#     game_id:      r11.game_id
#     ply:          r11.ply
#     mate_eval:    r11.mate_eval
#     regular_eval: r11.regular_eval
#     white_clock:  r12.white_clock
#     black_clock:  r12.black_clock
#
# JoinChain[r6]
#   JoinLink[inner, r0]
#     r6.game_id == r0.game_id
#   JoinLink[inner, r13]
#     r6.game_id == r13.game_id
#   values:
#     game_id:                   r6.game_id
#     is_rated:                  StartsWith(r0.event, start='Rated ')
#     lichess_time_control_type: Substring(IfElse(bool_expr=StartsWith(r0.event, start='Rated '), true_expr=StringSlice(r0.event, start=6), false_null_expr=r0.event), start=0, length=StringFind(IfElse(bool_expr=StartsWith(r0.event, start='Rated '), true_expr=StringSlice(r0.event, start=6), false_null_expr=r0.event), substr=' '))
#     is_tournament:             StringContains(haystack=r0.event, needle='tournament')
#     white_elo:                 Cast(r0.white_elo, to=int64)
#     black_elo:                 Cast(r0.black_elo, to=int64)
#     white_title:               r0.white_title
#     black_title:               r0.black_title
#     base_time:                 TryCast(Substring(r0.time_control, start=0, length=StringFind(r0.time_control, substr='+')), to=int64)
#     increment:                 TryCast(Substring(r0.time_control, start=StringFind(r0.time_control, substr='+') + 1), to=int64)
#     target:                    SimpleCase(base=r0.result, cases=['1-0', '1/2-1/2', '0-1'], results=[1, 0.5, 0], default=Cast(None, to=float64))
#     ply:                       r13.ply
#     mate_eval:                 r13.mate_eval
#     regular_eval:              r13.regular_eval
#     white_clock:               r13.white_clock
#     black_clock:               r13.black_clock

# %%
model_input_table_with_final_eval = model_input_table.mutate(
    mate_eval=model_input_table.mate_eval.coalesce(
        ibis.ifelse(
            model_input_table.regular_eval.isnull(),
            model_input_table.target.case()
            .when(1.0, MATE_SCORE)
            .when(0.0, -MATE_SCORE)
            .when(0.5, 0)
            .end(),
            None,
        )
    )
)

# %%
filtered_model_input_table = model_input_table_with_final_eval.filter(
    (model_input_table_with_final_eval.is_rated)
    & (model_input_table_with_final_eval.lichess_time_control_type != "Correspondence")
)

# %%
filtered_model_input_table.head().execute()
# Out:
#     game_id  is_rated lichess_time_control_type  is_tournament  white_elo  \
# 0  CgOuBqqM      True                     Blitz          False       1450
# 1  CgOuBqqM      True                     Blitz          False       1450
# 2  CgOuBqqM      True                     Blitz          False       1450
# 3  CgOuBqqM      True                     Blitz          False       1450
# 4  CgOuBqqM      True                     Blitz          False       1450
#
#    black_elo white_title black_title  base_time  increment  target  ply  \
# 0       1160        None        None        300          3     0.0    1
# 1       1160        None        None        300          3     0.0    2
# 2       1160        None        None        300          3     0.0    3
# 3       1160        None        None        300          3     0.0    4
# 4       1160        None        None        300          3     0.0    5
#
#   mate_eval  regular_eval  white_clock  black_clock
# 0      None         -0.09        300.0        300.0
# 1      None          0.07        300.0        300.0
# 2      None         -0.59        301.0        300.0
# 3      None         -0.60        301.0        301.0
# 4      None         -0.80        302.0        301.0

# %%
filtered_model_input_table.count().to_pyarrow().as_py()
# Out:
# 512257915

# %% [markdown]
# # Apply IbisML recipe

# %%
import pickle

xgb_recipe = pickle.load(open("xgb-recipe.pkl", "rb"))
xgb_recipe.to_ibis(filtered_model_input_table).head().execute()
# Out:
#    is_tournament  white_elo  black_elo  base_time  increment  target  ply  \
# 0            0.0     1685.0     1633.0      300.0        3.0     1.0  1.0
# 1            0.0     1685.0     1633.0      300.0        3.0     1.0  2.0
# 2            0.0     1685.0     1633.0      300.0        3.0     1.0  3.0
# 3            0.0     1685.0     1633.0      300.0        3.0     1.0  4.0
# 4            0.0     1685.0     1633.0      300.0        3.0     1.0  5.0
#
#    mate_eval  regular_eval  white_clock  black_clock  relative_clock_diff  \
# 0        NaN          0.18        300.0        300.0             0.000000
# 1        NaN          0.21        300.0        300.0             0.000000
# 2        NaN          0.08        303.0        300.0             0.007143
# 3        NaN          0.08        303.0        302.0             0.002381
# 4        NaN          0.11        306.0        302.0             0.009524
#
#    elo_diff
# 0      52.0
# 1      52.0
# 2      52.0
# 3      52.0
# 4      52.0

# %%
xgb_recipe.to_ibis(filtered_model_input_table).count().to_pyarrow().as_py()
# Out:
# 512257915
